# %% [markdown]
# # Homework 3:

# %% [markdown]
# ### **Conceptual:** Short answer questions. Be concise

# %% [markdown]
# ---
#
# 1. Using the mean squared error (MSE) as your objective function allows for a closed form solution to finding the maximum likelihood estimate (MLE) of your model parameters in linear regression. Let’s consider the simple, single predictor variable model $Y= \beta_0 + \beta_1 X $.
#
# a) Use algebra to show how you can expand out the MSE to get from i to ii below. Do your proof using Latex equation formatting.

# %% [markdown]
#  _i)_ $MSE(\beta_0, \beta_1)=E[ (Y-(\beta_0 + \beta_1 X))^2]$

# %% [markdown]
# **Answer:**

# %% [markdown]
# $$ MSE(\hat{\beta}_0, \hat{\beta}_1) = E[(Y - (\hat{\beta}_0 + \hat{\beta}_1X))^2] \\
# = E[Y^2] - 2\hat{\beta}_0E[Y] - 2\hat{\beta}_1E[XY] + E[(\hat{\beta}_0 + \hat{\beta}_1X)^2] \\
# = E[Y^2] - 2\hat{\beta}_0 E[Y] - 2\hat{\beta}_1(Cov[XY]+E[X]E[Y]) + \hat{\beta}_0^2 + 2\hat{\beta}_0\hat{\beta}_1E[X] + \hat{\beta}_1^2E[X^2] \\
# = E[Y^2] - 2\hat{\beta}_0 E[Y] - 2\hat{\beta}_1Cov[XY] - 2\hat{\beta}_1E[X]E[Y] + \hat{\beta}_0^2 + 2\hat{\beta}_0\hat{\beta}_1E[X] + \hat{\beta}_1^2Var[X] + \hat{\beta}_1^2(E[X])^2
# $$

# %% [markdown]
# b) Prove that the MLE of $\beta_0$ is $E[Y]- \beta_1 E[X]$ by taking the derivative of _ii_ above, with respect to $\beta_0$, setting the derivative to zero, and solving for $\beta_0$.

# %% [markdown]
# **Answer:**
# = $$E[Y^2] - 2\hat{\beta}_0 E[Y] - 2\hat{\beta}_1Cov[XY] - 2\hat{\beta}_1E[X]E[Y] + \hat{\beta}_0^2 + 2\hat{\beta}_0\hat{\beta}_1E[X] + \hat{\beta}_1^2Var[X] + \hat{\beta}_1^2(E[X])^2
# $$
#
# $$= -2E[y] -2\hat{\beta}_0 + 2\hat{\beta}_1E[x]$$
#
# $$-2\hat{\beta}_0 = -2E[y] + 2\hat{\beta}_1E[x]$$
#
# $$E[Y]- \beta_1 E[X]$$

# %% [markdown]
# c) Prove that the MLE for $\beta_1$ is $Cov[X,Y]/Var[X]$ by taking the derivative of _ii_ above, with respect to $\beta_1$, setting the derivative to zero, and solving for $\beta_1$.

# %% [markdown]
# **Answer:**
# = $$E[Y^2] - 2\hat{\beta}_0 E[Y] - 2\hat{\beta}_1Cov[XY] - 2\hat{\beta}_1E[X]E[Y] + \hat{\beta}_0^2 + 2\hat{\beta}_0\hat{\beta}_1E[X] + \hat{\beta}_1^2Var[X] + \hat{\beta}_1^2(E[X])^2
# $$
#  $ 0 =  -2Cov[XY] -2E[X]E[Y] + 2\beta_0E[X] + 2\beta_1Var[X] + 2\beta_1(E[X])^2 $
#
# $ - 2\beta_1Var[X] - 2\beta_1(E[X])^2 =  -2Cov[XY] -2E[X]E[Y] + 2\beta_1(E[X])^2 $
#
# $$-2\hat{\beta}_1cov[xy] - 2 E[x]E[x] + \hat{\beta}_1^2Var[X]$$
# $$Cov[X,Y]/Var[X]$$

# %% [markdown]
# ---
#
# 2. Using the MLE solutions shown in 1(b) and 1(c) above, show how, in the case of simple linear regression, the least squares line always passes through the point $(E(X), E(Y))$ or $(x,y)$). What does this imply about the leverage that the response and predictor variable means have on the ordinary least squares solution?

# %% [markdown]
# **Answer:**
# $$\hat{\beta}_0 = y - \hat{\beta}_1x$$
# $$E[Y]- \beta_1 E[X] = y - \hat{\beta}_1x$$
# $$E[Y] = y$$
# $$y = y$$

# %% [markdown]
# ---
# 3. In the case where X and Y are standard normal variables (i.e. $N(0,1)$), show that the ordinary least squares solution converges to the same solution as the Pearson correlation coefficient $r=Cov[X,Y]/(\sigma_X * \sigma_Y)$. What exactly do they both converge to?

# %% [markdown]
# **Answer:**
# $$ X \sim N(0, 1) $$
# $$ Y \sim N(0, 1) $$
#
# MLE -> regression
#
#  $$ \hat{\beta} = \frac{ \sum_{i=1}^{n} (x_i-\bar{x})(y_i - \bar{y})} {\sum_{i=1}^{n} (x_i - \bar{x})^2} \\
#  =  \frac{\sum_{i=1}^{n} (x_i-\bar{x})(y_i - \bar{y})}{1} \\
#  = Cov[X,Y]$$
#
# back to correlation
#
#  $$ r = \frac{ \sum_{i=1}^{n} (x_i-\bar{x})(y_i - \bar{y})} {\sum_{i=1}^{n} \sqrt{(x_i - \bar{x})^2}  \sqrt{(y_i - \bar{y})^2}} \\
#  =  \frac{ \sum_{i=1}^{n} (x_i-\bar{x})(y_i - \bar{y})} {\sqrt{1}  \sqrt{1}} \\
#  = Cov[X,Y] $$

# %% [markdown]
# ---
#
# 4. Three methods for evaluating a regression model’s performance are $r^2$, $RSE$, and the $F$ Test. Show the functional form of each method and describe conceptually what it is telling you about your model.

# %% [markdown]
# **Answer:**
#
#
# R2 proportion variance explained. Where RSS is residual error – error not explained not explained by the model. TSS is the sum, over all observations, of the squared differences of each observation from the overall mean. So, ass RSS decreases R2 increases.
#
# $$ r^2 = \frac{TSS-RSS}{TSS} = 1 - \frac{RSS}{TSS} = 1 - \frac{\sum_{i=1}^{n} (y_i - \hat{y}_i)^2} {\sum_{i=1}^{n} (y_i - \bar{y})^2}$$
#
# RSE is analogous to the variance in the model.  Given that we want to control for the most variance possible, the smaller the RSS (numerator of the function utilized to estimate RSE) the lower the variance or RSE will be.
#
# $$ RSE = \sigma_{model}^2 = \sqrt{ \frac{RSS}{n-2} } = \sqrt{ \frac{ \sum_{i=1}^{n} (y-\hat{y})^2 }{n-2} }$$
#
#
#
# However, rather than be reflected as a strict ratio that is constrained between 0 & 1 (like 𝑟2r2), the F-statistic can be any positive number since it is using RSS as the denominator, rather than TSS. Thus, what the F-statistic is telling you is whether the variance not explained by your model (TSS) is greater than the variance explained your model (RSS), if so then the ratio is high.
#
# $$ F = \frac{\sigma_{between}^2}{\sigma_{within}^2} = \frac{ \sum_{i=1}^{k} \frac{n_i(y_i - \bar{y})^2}{K-1}} {\frac{ \sum_{i=1}^{k} \sum_{j=1}^{n_i} (y_{i,j} - \bar{y}_i)^2 } {N-K} }  $$

# %% [markdown]
# ---
# 5. Suppose that we have a dataset with five predictors, $X_1 = GPA$, $X_2 = IQ$, $X_3 = Gender$ (1 for Female and 0 for Male), $X_4$ = Interaction between GPA and IQ, and $X_5$ = Interaction between GPA and Gender. The response variable ($Y$) is starting salary after graduation (in thousands of dollars). Suppose we use least squares to fit the model, and get $\hat{\beta_0}$ =50, $\hat{\beta_1}$ =20, $\hat{\beta_2}$ =0.07, $\hat{\beta_3}$ =35, $\hat{\beta_4}$ =0.01, $\hat{\beta_5}$ =-10.

# %% [markdown]
# a) Which answer is correct, and why?
#
# i. For a fixed value of IQ and GPA, males earn more on average than females.
#
# ii. For a fixed value of IQ and GPA, females earn more on average than males.
#
# iii. For a fixed value of IQ and GPA, males earn more on average than females provided that the GPA is high enough.
#
# iv. For a fixed value of IQ and GPA, females earn more on average than males provided that the GPA is high enough.

# %% [markdown]
# **Answer:**
# iii.  Given that the main effects for iq, gpa, and interaction between iq and GPA and the intercept are constant for both sexes we only care about the geneder gpa interaction and gender main effect.

# %% [markdown]
# (b) Predict the salary of a female graduate with IQ of 110 and a GPA of 4.0.

# %% [markdown]
# **Answer:**
# $137100

# %% [markdown]
# (c) True or false: Since the coefficient for the GPA/IQ interaction term is very small, there is very little evidence of an interaction effect. Justify your answer.

# %% [markdown]
# **Answer:**
# False,  interacttions aeffects cannot be compared unless they are standardized.

# %% [markdown]
# ---
# 6. What are high leverage observations? How do they impact your model fits? What assumption of linear regression do they violate?

# %% [markdown]
# **Answer:**
#
# High leverage points modulate the slope of the regression line in a manner that is not consistent with the majority of the distribution. Leverage points will force the regression line to follow a linear trend that is not consistent with the rest of the data.

# %% [markdown]
# ---
# 7. A linear mixed effect model has the form $Y = X\beta + Z\upsilon + \epsilon$.

# %% [markdown]
# a) What are the assumptions about $Z$ and $\upsilon$ that make this different from using a regular control variable in a simple linear regression model?

# %% [markdown]
# **Answer:** Given that nu and Z are random, we cannot assume a unit increase will result in the same unit increase in Y. It can influence Y in two seperate ways.

# %% [markdown]
# b) What is the objective function for this model (i.e., the function that needs to be minimized to find the optimal parameters) and how is it different than the objective function for the ordinary least squares model?

# %% [markdown]
# $$min(||Y-X\beta-Z\Lambda_{\theta}\upsilon||^2+||\upsilon||^2)$$
#
# nu2 limiting impact nu on beta. Which in turn limits the impact of the coefficients effectin the mixed effect model function.

# %% [markdown]
# c) What advantage does including a random effects term in your model give you with regards to understanding the fixed effects relationship?

# %% [markdown]
# **Answer:**
# Without any random effects an overall estimaton of error is estimated of the linear model. However, when random effects are included each random variable is provided with a unique error estimate.  This allows for parsing out such random effects  which results in controlling for more error.

# %% [markdown]
# ---
#
# ### **Applied:** Show your code & plots
#
# (Include conceptual answers to questions as comments in code cells)

# %% [markdown]
# ---
# 8. Load the cbpp dataset from the lme4 library. Run ?cbpp after loading the lme4 library to get information on the dataset.
#
# (a) Plot the relationship between herd size and CBPP incidence
#
# (b) Use the lm function to model the effect of herd size (predictor) on CBPP incidence (response). How does herd size impact disease rate? Report the results of the model.
#
# (c) Use the lmer function to include the herd identifier as a random effect. How does this impact the fixed effect of herd size on CBPP incidence?
#
# (d) Compare the simple linear model (i.e., the fixed effects only model) with the mixed effect model using AIC (https://en.wikipedia.org/wiki/Akaike_information_criterion). Does adding the random effect to the model improve or change the fixed effect?

# %%
library(lme4)
library(ggplot2)
data <- cbpp
ggplot(data = data, aes(x = size, y = incidence)) + geom_point()
lm1 <- lm(incidence ~ size, data = data)
summary(lm1)
#Lmer
lmer1 <- lmer(incidence ~ size + (1|herd), data = data)
summary(lmer1)

AIC(lm1)
AIC(lmer1)
# Out:
# Call:
# lm(formula = incidence ~ size, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.1456 -1.5925 -0.4864  0.8006  8.6840
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.31106    0.73554  -0.423  0.67405
# size         0.13827    0.04389   3.150  0.00266 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.432 on 54 degrees of freedom
# Multiple R-squared:  0.1553,	Adjusted R-squared:  0.1396
# F-statistic: 9.926 on 1 and 54 DF,  p-value: 0.002657
# Linear mixed model fit by REML ['lmerMod']
# Formula: incidence ~ size + (1 | herd)
#    Data: data
#
# REML criterion at convergence: 257.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.7326 -0.4817 -0.1526  0.3818  3.0017
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  herd     (Intercept) 2.833    1.683
#  Residual             4.058    2.015
# ...

# %% [markdown]
# When plotting the herd data and examining the simple regression model, the data suggests that as heard size increases so does the incidence of disease.
#
# When a random effect is added for herd, the beta value for the fixed effect increases.
#
# The AIC for the lmer model is slightly higher 265 than the model run with OLS regression (262).  However, given that there is an extra parameter this is expected given that AIC penalizes models with increased numbers of parameters.

# %% [markdown]
# ---
#
#
# 9. This question involves the use of multiple linear regression on the _Auto_ data set. (From ISLR Chapter 3, Exercise #9)
#
# (a) Produce a scatterplot matrix which includes all of the variables in the data set.
#
# (b) Compute the matrix of correlations between the variables using the function _cor()_. You will need to exclude the name variable, which is qualitative.
#
# (c) Use the _lm()_ function to perform a multiple linear regression with mpg as the response and all other variables except name as the predictors. Use the _summary()_ function to print the results. Comment on the output. For instance:
#
# i. Is there a relationship between the predictors and the response?
#
# ii. Which predictors appear to have a statistically significant relationship to the response?
#
# iii. What does the coefficient for the year variable suggest?
#
# (d) Use the _plot()_ function to produce diagnostic plots of the linear regression fit. Comment on any problems you see with the fit. Do the residual plots suggest any unusually large outliers? Does the leverage plot identify any observations with unusually high leverage?
#
# (e) Use the _*_ and _:_ symbols to fit linear regression models with interaction effects. Do any interactions appear to be statistically significant?
#
# (f) Try a few different transformations of the variables, such as log(X), √X, X2. Comment on your findings.

# %%
# -------------------------------
# Question 9
# -------------------------------
library(ISLR)
#A
pairs(Auto, upper.panel = NULL)
#B
auto_2 <- Auto[,1:8]
cor(auto_2)
#C
mpg_lm <- lm(mpg ~ . , data = auto_2)
summary(mpg_lm)

plot(mpg_lm)

#E
lmandmore <- lm(mpg ~ cylinders * displacement + horsepower * weight, auto_2)
summary(lmandmore)

#D
plot(log(Auto$weight), Auto$mpg)
plot(sqrt(Auto$weight), Auto$mpg)
plot((Auto$weight)^2, Auto$mpg)
# Out:
#              mpg        cylinders  displacement horsepower weight
# mpg           1.0000000 -0.7776175 -0.8051269   -0.7784268 -0.8322442
# cylinders    -0.7776175  1.0000000  0.9508233    0.8429834  0.8975273
# displacement -0.8051269  0.9508233  1.0000000    0.8972570  0.9329944
# horsepower   -0.7784268  0.8429834  0.8972570    1.0000000  0.8645377
# weight       -0.8322442  0.8975273  0.9329944    0.8645377  1.0000000
# acceleration  0.4233285 -0.5046834 -0.5438005   -0.6891955 -0.4168392
# year          0.5805410 -0.3456474 -0.3698552   -0.4163615 -0.3091199
# origin        0.5652088 -0.5689316 -0.6145351   -0.4551715 -0.5850054
#              acceleration year       origin
# mpg           0.4233285    0.5805410  0.5652088
# cylinders    -0.5046834   -0.3456474 -0.5689316
# displacement -0.5438005   -0.3698552 -0.6145351
# horsepower   -0.6891955   -0.4163615 -0.4551715
# weight       -0.4168392   -0.3091199 -0.5850054
# acceleration  1.0000000    0.2903161  0.2127458
# ...

# %% [markdown]
# C: The year, origin, weight, and displacement share a significant relationship with mpg.  As expected, weight shares a negative relationship with mpg indicating that as weight increases, mpg decreases.  The year, origin, and displacement all share a positive relationship with mpg and as they increase, so does MPG.  No other predictors shared a relaltionship that significantlly modulated mpg. When interpreting year, it can be assumed that when all other predictors are held constant, mpg increases by .75 with the increase of 1 year.
#
# D:
# The QQ plot suggests that the data set is slightly not linear towards the upper end of the values continuum.
#
# When the standarized residuals and are plotted with the leverage points, we can see that data point 12 is a leverage point.
#
# E)
# The interactions between horsepower and weight and displacement and cylinders are both significant. However, their beta values are quite small.
#
# D) Both the log and square root of weight appear to create a more linear relationship with mpg.

# %% [markdown]
# ---
#
# 10. This question should be answered using the _Carseats_ data set. (From ISLR Chapter 3, Exercise #10)
#
# (a) Fit a multiple regression model to predict Sales using Price,
# Urban, and US.
#
# (b) Provide an interpretation of each coefficient in the model. Be
# careful—some of the variables in the model are qualitative!
#
# (c) Write out the model in equation form, being careful to handle the qualitative variables properly.
#
# (d) For which of the predictors can you reject the null hypothesis $H_0 : \beta_j = 0$?
#
# (e) On the basis of your response to the previous question, fit a smaller model that only uses the predictors for which there is evidence of association with the outcome.
#
# (f) How well do the models in (a) and (e) fit the data?
#
# (g) Using the model from (e), obtain 95% confidence intervals for the coefficient(s).
#
# (h) Is there evidence of outliers or high leverage observations in the model from (e)?

# %%
# -------------------------------
# Question 10
# -------------------------------

# INSERT CODE HERE
data(Carseats)
carseat1 <- lm(Sales ~ Price + Urban + US, data = Carseats)
summary(carseat1)
carseat2 <- lm(Sales ~ Price + US, data = Carseats)
summary(carseat2)
confint(carseat2)
plot(carseat2)
# Out:
# Call:
# lm(formula = Sales ~ Price + Urban + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036  < 2e-16 ***
# Price       -0.054459   0.005242 -10.389  < 2e-16 ***
# UrbanYes    -0.021916   0.271650  -0.081    0.936
# USYes        1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = Sales ~ Price + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652  < 2e-16 ***
# ...

# %% [markdown]
# B:
# Holding all other values constant, as price increases the number of units sold  decreases. If the carseat is sold in the US the number of units sold increases.
# C:
# $$Sales=13.04 −0.05×Price - 0.02 × Urban + 1.2×US + ε$$
# D:
# Price and US sold (yes)
# F: The models fit for both models is mediocre and both control for 23% of the variance in the data.
# H: The leverage plot does show a few outliers.

# %% [markdown]
# ---
#
# 11. In this exercise you will create some simulated data and will fit simple linear regression models to it. Make sure to use _set.seed(1)_ prior to starting part (a) to ensure consistent results. (From ISLR Chapter 3, Exercise #13)
#
# (a) Using the _rnorm()_ function, create a vector, $x$, containing 100 observations drawn from a N(0,1) distribution. This represents a feature, $X$.
#
# (b) Using the _rnorm()_ function, create a vector, eps, containing 100 observations drawn from a N(0,0.25) distribution i.e. a normal distribution with mean zero and variance 0.25.
#
# (c) Using x and eps, generate a vector y according to the model
#
# $$ Y = -1 + 0.5X + \epsilon $$
#
# What is the length of the vector $y$? What are the values of $\beta_0$ and $\beta_1$ in this linear model?
#
# (d) Create a scatterplot displaying the relationship between $x$ and $y$. Comment on what you observe.
#
# (e) Fit a least squares linear model to predict y using x. Comment on the model obtained. How do $\hat{\beta_0}$ and $\hat{\beta_1}$ compare to $\beta_0$ and $\beta_1$?
#
# (f) Display the least squares line on the scatterplot obtained in (d). Draw the population regression line on the plot, in a different color. Use the _legend()_ command to create an appropriate legend.
#
# (g) Now fit a polynomial regression model that predicts $y$ using $x$ and $x^2$. Is there evidence that the quadratic term improves the model fit? Explain your answer.
#
# (h) Repeat (a)–(f) after modifying the data generation process in such a way that there is less noise in the data. The model in (c) should remain the same. You can do this by decreasing the variance of the normal distribution used to generate the error term $\epsilon$ in (b). Describe your results.
#
# (i) Repeat (a)–(f) after modifying the data generation process in such a way that there is more noise in the data. The model in (c) should remain the same. You can do this by increasing the variance of the normal distribution used to generate the error term $\epsilon$ in (b). Describe your results.
#
# (j) What are the confidence intervals for $\beta_0$ and $\beta_1$ based on the original data set, the noisier data set, and the less noisy data set? Comment on your results.

# %%
# -------------------------------
# Question 11
# -------------------------------

#a
set.seed(1)
x <- rnorm(100)
#b
eps <- rnorm(100, sd = sqrt(0.25))
#c
y <- -1 + .5*x + eps
#d
plot(x,y)
#e
lm(y~x)
#f

data <- data.frame(x =x,
                   y = y)

plot1 <- ggplot(data = data, aes(x = x, y = y)) + geom_point() + geom_abline(slope = .5, intercept = -1) + 
  geom_smooth(method = lm, se = FALSE)
#g
poly <- lm(y ~ x + (x^2) + eps, data = data)
summary(poly)

#h
eps_small <- rnorm(100, sd = sqrt(0.025))
y_mod1 <- -1 + .5*x + eps_small
data2 <- data.frame(x =x,
                   y = y_mod1)
library(ggplot2)
plot2 <- ggplot(data= data2, aes(x = x, y = y)) + geom_point() + geom_abline(slope = .5, intercept = -1) + 
  geom_smooth(method = lm, se = FALSE)

eps_big <- rnorm(100, sd = sqrt(5))
y_mod2 <- -1 + .5*x + eps_big

data3 <- data.frame(x =x,
                   y = y_mod2,
                   eps = eps_big)

plot3 <- ggplot(data= data3, aes(x = x, y = y)) + geom_point() + geom_abline(slope = .5, intercept = -1) + 
  geom_smooth(method = lm, se = FALSE)

library(gridExtra)
grid.arrange(plot1,plot2,plot3)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#     -1.0188       0.4995
# Warning message in summary.lm(poly):
# “essentially perfect fit: summary may be unreliable”
# Call:
# lm(formula = y ~ x + (x^2) + eps, data = data)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -9.746e-16 -3.469e-17 -6.300e-19  6.694e-17  1.693e-16
#
# Coefficients:
#               Estimate Std. Error    t value Pr(>|t|)
# (Intercept) -1.000e+00  1.270e-17 -7.873e+16   <2e-16 ***
# x            5.000e-01  1.410e-17  3.547e+16   <2e-16 ***
# eps          1.000e+00  2.644e-17  3.782e+16   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.26e-16 on 97 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:      1
# F-statistic: 1.343e+33 on 2 and 97 DF,  p-value: < 2.2e-16
# plot without title
# plot without title

# %% [markdown]
# C: 100
#
# D: It looks like x and y share a linear relatonship, but with a wide confidece interval on the slope. $\beta_0$ and $\beta_1$ are -1 and .5, respectively.
#
# E: Given this is an approximiation of the data we gave the estimates beta should be close to the observed betas.  Here we find that $\hat\beta_0$ is -1.01 and  $\hat\beta_1$ is 0.5.

# %%
model1 <- lm(y~x, data)
confint(model1)
model2 <- lm(y~x, data2)       
confint(model2)
model3<-lm(y~x, data3)
confint(model3)
# Out:
#             2.5 %      97.5 %
# (Intercept) -1.1150804 -0.9226122
# x            0.3925794  0.6063602
#             2.5 %      97.5 %
# (Intercept) -1.0285258 -0.9628195
# x            0.4668557  0.5398379
#             2.5 %      97.5 %
# (Intercept) -1.3160457 -0.4260669
# x           -0.1187824  0.8697468

# %% [markdown]
# We find that as SD increases the confidence interfals widen and as SD decreases the confidence intervals get samller.
